# %% [markdown]
# # Build vocabulary and tokenizer
# 본 노트에서는 자연어처리 관련 딥러닝 모형학습을 위한 필수적인 전처리중 하나로 training corpus에 존재하는 token들의 집합인 **vocabulary**를 만들어 봅니다. vocabulary 구성 자체는 미리 제공하는 `Vocab` class를 활용해봅니다. 또한 미리 제공하는 `Tokenizer` class를 같이 활용하여, 효율적인 전처리를 어떻게 할 수 있는 지 확인합니다.

# %% [markdown]
# ### Setup

# %%
import sys
import itertools
import pandas as pd
from pathlib import Path
from pprint import pprint
from typing import List
from collections import Counter
from utils import Vocab, Tokenizer

# %% [markdown]
# ### Load dataset

# %%
data_dir = Path.cwd() / 'data'
list_of_dataset = list(data_dir.iterdir())
pprint(list_of_dataset)
# Out:
# [PosixPath('/root/Documents/archive/strnlp/exercise/data/train.txt'),
#  PosixPath('/root/Documents/archive/strnlp/exercise/data/validation.txt'),
#  PosixPath('/root/Documents/archive/strnlp/exercise/data/test.txt')]

# %%
tr_dataset = pd.read_csv(list_of_dataset[1], sep='\t')
tr_dataset.head()
# Out:
#                                        document  label
# 0  60년대 각본을 가져다가 만든거 같이 진부하고 춤도 이박사 춤이 더 나을거 같음      0
# 1                                        아 신난다~      0
# 2                                 이게 한쿡영화의 현실..      0
# 3                                박철수가 만들었다니 ...      0
# 4                    와 항상 금요일이 기대되네요ㅠ 몬스타 화이팅 !      1

# %% [markdown]
# ### Split training corpus and count each tokens
# 앞선 `eda.ipynb` 노트에서 활용헌 `split_eojeol` function을 이용, **training corpus를 sequence of tokens의 형태로 변환하고, training corpus에서 token의 출현빈도를 계산합니다.**

# %%
# 문장을 어절기준으로 보는 split_fn을 작성
def split_eojeol(s: str) -> List[str]:
    return s.split(' ')

# %%
training_corpus = tr_dataset['document'].apply(lambda sen: split_eojeol(sen)).tolist()
pprint(training_corpus[:5])
# Out:
# [['60년대',
#   '각본을',
#   '가져다가',
#   '만든거',
#   '같이',
#   '진부하고',
#   '춤도',
#   '이박사',
#   '춤이',
#   '더',
#   '나을거',
#   '같음'],
#  ['아', '신난다~'],
#  ['이게', '한쿡영화의', '현실..'],
#  ['박철수가', '만들었다니', '...'],
#  ['와', '항상', '금요일이', '기대되네요ㅠ', '몬스타', '화이팅', '!']]

# %%
count_tokens = Counter(itertools.chain.from_iterable(training_corpus))
print(len(count_tokens))
# Out:
# 98220

# %% [markdown]
# ### Build vocab
# `min_freq`를 설정하고, training corpus에서 출현빈도가 `min_freq`보다 낮은 token을 제외하고, `Vocab` class를 이용하여 Vocabulary를 구축합니다. `min_freq`보다 낮은 token들은 `unknown`으로 처리됩니다.
#
# 1. `list_of_tokens`을 만듭니다. `list_of_tokens`은 `min_freq`보다 낮은 token들을 모아놓은 `list`입니다.
# 2. `vocab`을 만듭니다. `list_of_tokens`를 parameter로 전달받습니다.

# %%
min_freq = 5
list_of_tokens = [token for token in count_tokens.keys() if count_tokens.get(token) > min_freq]
print(len(list_of_tokens))
# Out:
# 4381

# %% [markdown]
# `Vocab` class는 `list_of_tokens`를 parameter로 전달받아 아래와 같이 생성합니다.

# %%
vocab = Vocab(list_of_tokens=list_of_tokens, bos_token=None, eos_token=None, unknown_token_idx=0)

# %% [markdown]
# ### How to use `Vocab`
# `list_of_tokens`로 생성한 `Vocab` class의 instance인 `vocab`은 아래와 같은 멤버들을 가지고 있습니다.

# %%
help(Vocab)
# Out:
# Help on class Vocab in module utils:
#
# class Vocab(builtins.object)
#  |  Methods defined here:
#  |
#  |  __init__(self, list_of_tokens=None, padding_token='<pad>', unknown_token='<unk>', bos_token='<bos>', eos_token='<eos>', reserved_tokens=None, unknown_token_idx=0)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __len__(self)
#  |
#  |  to_indices(self, tokens:Union[str, List[str]]) -> Union[int, List[int]]
#  |
#  |  to_tokens(self, indices:Union[int, List[int]]) -> Union[str, List[str]]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  bos_token
#  |
#  |  embedding
#  |
#  |  eos_token
#  |
#  |  idx_to_token
#  |
#  |  padding_token
#  |
#  |  token_to_idx
#  |
#  |  unknown_token

# %%
# padding_token, unknown_token, eos_token, bos_token
print(vocab.padding_token)
print(vocab.unknown_token)
print(vocab.eos_token)
print(vocab.bos_token)
# Out:
# <pad>
# <unk>
# None
# None

# %%
# token_to_idx
print(vocab.token_to_idx)
# Out:
# {'<unk>': 0, '<pad>': 1, '각본을': 2, '같이': 3, '진부하고': 4, '더': 5, '같음': 6, '아': 7, '이게': 8, '...': 9, '와': 10, '항상': 11, '화이팅': 12, '!': 13, '이제': 14, '나이': 15, '예전': 16, '같지': 17, '않아': 18, '아~': 19, '그리고': 20, '마지막': 21, '장면': 22, '그닥': 23, '웃기지도': 24, '포스터': 25, '좀': 26, '듯..': 27, '일단': 28, '다': 29, '여주': 30, '미친듯이': 31, '정말': 32, '연기력에': 33, '박수를': 34, '완벽하게': 35, '잘': 36, '명작이다': 37, '전편의': 38, '기대하고': 39, '뭐지?': 40, '훈훈한': 41, '그저': 42, '뿐': 43, '이': 44, '영화는': 45, '너무': 46, '연기': 47, '할': 48, '필요': 49, '없는': 50, '영화를': 51, '선택한': 52, '로맨틱': 53, '제발': 54, '이건': 55, '공포가': 56, '공포를': 57, '내용도': 58, '없고': 59, '기분만': 60, '영화': 61, '작품': 62, '캐스팅': 63, '이유없이': 64, '싶은': 65, '아이들의': 66, '장난': 67, '슬픈': 68, '이걸': 69, '끝까지': 70, '본': 71, '내가': 72, '대단하다': 73, '1점도': 74, '아까움': 75, '20년이': 76, '그냥': 77, '시간': 78, '많은': 79, '것을': 80, '생각하게': 81, '하는': 82, '1편을': 83, '반도': 84, '못': 85, '차라리': 86, '볼만함': 87, '귀신': 88, '평점이': 89, '이영화가': 90, '왜': 91, '이해가': 92, '유치한': 93, '후반부에': 94, '아는': 95, '만큼': 96, '보이는': 97, '명작': 98, 'ㅋㅋㅋㅋ': 99, '평점': 100, '수많은': 101, '정작': 102, '제목처럼': 103, '스타일': 104, '가장': 105, '살린': 106, '그런지': 107, '졸작이': 108, '젠장': 109, '평점에': 110, '영화!': 111, '절대': 112, '보지': 113, '시간이': 114, '긴장을': 115, '놓은': 116, '보다가': 117, '예전에': 118, '좋지만': 119, '아이들이': 120, '보기에': 121, '생각.': 122, '두': 123, '스토리도': 124, '영상도': 125, '갑자기': 126, '교훈을': 127, '모르겠다.': 128, '아들이': 129, '있다는': 130, '건': 131, '일이다.': 132, '아이를': 133, '위해서': 134, '수': 135, '있는': 136, '행복한': 137, '아버지의': 138, '가족의': 139, '사랑을': 140, '독특한': 141, '소재로': 142, '그려낸': 143, '영화이다.': 144, '주제에': 145, '비해': 146, '이야기를': 147, '힘이': 148, '많이': 149, '아닙니다.': 150, '절대로': 151, '보지마세요': 152, '리얼': 153, '재밌음': 154, '이영화는': 155, '꼭': 156, '겨우': 157, '여자가': 158, '무슨': 159, '그러다': 160, '모두가': 161, '혼자': 162, '눈물이': 163, '대단한': 164, '영화로': 165, '완전': 166, '괜찮음': 167, '인디아나': 168, '중국판': 169, '감정을': 170, '표현한': 171, '것': 172, '같다.': 173, '바라보는': 174, '눈빛이': 175, '기억에': 176, '레알': 177, '최고로': 178, '억지스러운': 179, '영화.': 180, '내내': 181, '입이': 182, '아름다운': 183, '이야기.': 184, '달리': 185, '만들지': 186, '캐릭터,': 187, '목소리': 188, '그냥저냥': 189, '없어': 190, '내용이': 191, '솔직히': 192, '보면': 193, '정말로': 194, '위한': 195, '누가': 196, '눈빛': 197, '때문에': 198, '드라마가': 199, '한동안': 200, '감동입니다': 201, 'ㅠㅠㅠ': 202, '극장에서': 203, '실제': 204, '신선하고': 205, '재밌었는데': 206, 'ㅎ': 207, '30년': 208, '인생': 209, '첨으로': 210, '아까운': 211, '영화다..': 212, '이런': 213, '70년대': 214, '그당시': 215, '그': 216, '또는': 217, '2점': 218, '이렇게': 219, '형편없는': 220, '스토리에': 221, '그래도': 222, '연출은': 223, '열심히': 224, '한': 225, '티가': 226, '난다.': 227, '아니면': 228, '공포': 229, '다른': 230, '사람에게': 231, '결국': 232, '그의': 233, '것이': 234, '되었다.': 235, '좋다.': 236, '요즘': 237, '발': 238, '못한다': 239, '시간의': 240, '소중함을': 241, '잃어버린': 242, '볼': 243, '때마다': 244, '다소': 245, '여전히': 246, '매력적인': 247, '소재의': 248, '비슷한': 249, '번': 250, '아만다': 251, '찾아': 252, '보기': 253, '어려운': 254, '뭐야': 255, '이거': 256, '재밌다고': 257, '죄다': 258, '감독은': 259, '어떤': 260, '재미있게': 261, '만들': 262, '보면서': 263, '주인공': 264, '아이가': 265, '참': 266, '느꼈다.': 267, '생각을': 268, '결말': 269, '부분이': 270, '최고의': 271, '영화네요.': 272, '분들': 273, '연기에': 274, '갑니다.': 275, '안보면': 276, '나중에': 277, 'ㅠㅠ': 278, '왜이리': 279, '보다': 280, '^^': 281, '별': 282, '아니고': 283, '상당한': 284, '흥행을': 285, '했을': 286, '아쉬운': 287, '작품.': 288, '지금보면': 289, '부분도': 290, '보이지만': 291, '당시엔': 292, '킬링타임용': 293, '영화!!!': 294, '영화보다': 295, '나오는': 296, '노래가': 297, '에휴': 298, '사람은': 299, '최소': 300, '허술한': 301, '리메이크': 302, '계속': 303, '봐도': 304, '같다': 305, '어우': 306, '그렇다': 307, '쳐도': 308, '진짜...': 309, '지금이나': 310, '게': 311, 'dvd': 312, '후회': 313, '좋았던': 314, '드라마': 315, '가슴이': 316, '주는': 317, '시작부터': 318, '배우들': 319, '1편보다': 320, '재밌고': 321, '몰입감': 322, '있다.': 323, '연기도': 324, '특히': 325, '카메라': 326, '문득': 327, '얼굴이': 328, '배우': 329, '지금': 330, '불편한': 331, '엉성한': 332, '이딴걸': 333, '절로': 334, '전체적으로': 335, '넘': 336, '재밌었어요': 337, 'ㅎㅎ': 338, '딱': 339, '적당한': 340, '영화...': 341, '만든': 342, '코미디.': 343, '뭐': 344, '하나': 345, '제대로': 346, '없다': 347, '지금도': 348, '없다.': ...

# %%
# idx_to_token
print(vocab.idx_to_token)
# Out:
# {0: '<unk>', 1: '<pad>', 2: '각본을', 3: '같이', 4: '진부하고', 5: '더', 6: '같음', 7: '아', 8: '이게', 9: '...', 10: '와', 11: '항상', 12: '화이팅', 13: '!', 14: '이제', 15: '나이', 16: '예전', 17: '같지', 18: '않아', 19: '아~', 20: '그리고', 21: '마지막', 22: '장면', 23: '그닥', 24: '웃기지도', 25: '포스터', 26: '좀', 27: '듯..', 28: '일단', 29: '다', 30: '여주', 31: '미친듯이', 32: '정말', 33: '연기력에', 34: '박수를', 35: '완벽하게', 36: '잘', 37: '명작이다', 38: '전편의', 39: '기대하고', 40: '뭐지?', 41: '훈훈한', 42: '그저', 43: '뿐', 44: '이', 45: '영화는', 46: '너무', 47: '연기', 48: '할', 49: '필요', 50: '없는', 51: '영화를', 52: '선택한', 53: '로맨틱', 54: '제발', 55: '이건', 56: '공포가', 57: '공포를', 58: '내용도', 59: '없고', 60: '기분만', 61: '영화', 62: '작품', 63: '캐스팅', 64: '이유없이', 65: '싶은', 66: '아이들의', 67: '장난', 68: '슬픈', 69: '이걸', 70: '끝까지', 71: '본', 72: '내가', 73: '대단하다', 74: '1점도', 75: '아까움', 76: '20년이', 77: '그냥', 78: '시간', 79: '많은', 80: '것을', 81: '생각하게', 82: '하는', 83: '1편을', 84: '반도', 85: '못', 86: '차라리', 87: '볼만함', 88: '귀신', 89: '평점이', 90: '이영화가', 91: '왜', 92: '이해가', 93: '유치한', 94: '후반부에', 95: '아는', 96: '만큼', 97: '보이는', 98: '명작', 99: 'ㅋㅋㅋㅋ', 100: '평점', 101: '수많은', 102: '정작', 103: '제목처럼', 104: '스타일', 105: '가장', 106: '살린', 107: '그런지', 108: '졸작이', 109: '젠장', 110: '평점에', 111: '영화!', 112: '절대', 113: '보지', 114: '시간이', 115: '긴장을', 116: '놓은', 117: '보다가', 118: '예전에', 119: '좋지만', 120: '아이들이', 121: '보기에', 122: '생각.', 123: '두', 124: '스토리도', 125: '영상도', 126: '갑자기', 127: '교훈을', 128: '모르겠다.', 129: '아들이', 130: '있다는', 131: '건', 132: '일이다.', 133: '아이를', 134: '위해서', 135: '수', 136: '있는', 137: '행복한', 138: '아버지의', 139: '가족의', 140: '사랑을', 141: '독특한', 142: '소재로', 143: '그려낸', 144: '영화이다.', 145: '주제에', 146: '비해', 147: '이야기를', 148: '힘이', 149: '많이', 150: '아닙니다.', 151: '절대로', 152: '보지마세요', 153: '리얼', 154: '재밌음', 155: '이영화는', 156: '꼭', 157: '겨우', 158: '여자가', 159: '무슨', 160: '그러다', 161: '모두가', 162: '혼자', 163: '눈물이', 164: '대단한', 165: '영화로', 166: '완전', 167: '괜찮음', 168: '인디아나', 169: '중국판', 170: '감정을', 171: '표현한', 172: '것', 173: '같다.', 174: '바라보는', 175: '눈빛이', 176: '기억에', 177: '레알', 178: '최고로', 179: '억지스러운', 180: '영화.', 181: '내내', 182: '입이', 183: '아름다운', 184: '이야기.', 185: '달리', 186: '만들지', 187: '캐릭터,', 188: '목소리', 189: '그냥저냥', 190: '없어', 191: '내용이', 192: '솔직히', 193: '보면', 194: '정말로', 195: '위한', 196: '누가', 197: '눈빛', 198: '때문에', 199: '드라마가', 200: '한동안', 201: '감동입니다', 202: 'ㅠㅠㅠ', 203: '극장에서', 204: '실제', 205: '신선하고', 206: '재밌었는데', 207: 'ㅎ', 208: '30년', 209: '인생', 210: '첨으로', 211: '아까운', 212: '영화다..', 213: '이런', 214: '70년대', 215: '그당시', 216: '그', 217: '또는', 218: '2점', 219: '이렇게', 220: '형편없는', 221: '스토리에', 222: '그래도', 223: '연출은', 224: '열심히', 225: '한', 226: '티가', 227: '난다.', 228: '아니면', 229: '공포', 230: '다른', 231: '사람에게', 232: '결국', 233: '그의', 234: '것이', 235: '되었다.', 236: '좋다.', 237: '요즘', 238: '발', 239: '못한다', 240: '시간의', 241: '소중함을', 242: '잃어버린', 243: '볼', 244: '때마다', 245: '다소', 246: '여전히', 247: '매력적인', 248: '소재의', 249: '비슷한', 250: '번', 251: '아만다', 252: '찾아', 253: '보기', 254: '어려운', 255: '뭐야', 256: '이거', 257: '재밌다고', 258: '죄다', 259: '감독은', 260: '어떤', 261: '재미있게', 262: '만들', 263: '보면서', 264: '주인공', 265: '아이가', 266: '참', 267: '느꼈다.', 268: '생각을', 269: '결말', 270: '부분이', 271: '최고의', 272: '영화네요.', 273: '분들', 274: '연기에', 275: '갑니다.', 276: '안보면', 277: '나중에', 278: 'ㅠㅠ', 279: '왜이리', 280: '보다', 281: '^^', 282: '별', 283: '아니고', 284: '상당한', 285: '흥행을', 286: '했을', 287: '아쉬운', 288: '작품.', 289: '지금보면', 290: '부분도', 291: '보이지만', 292: '당시엔', 293: '킬링타임용', 294: '영화!!!', 295: '영화보다', 296: '나오는', 297: '노래가', 298: '에휴', 299: '사람은', 300: '최소', 301: '허술한', 302: '리메이크', 303: '계속', 304: '봐도', 305: '같다', 306: '어우', 307: '그렇다', 308: '쳐도', 309: '진짜...', 310: '지금이나', 311: '게', 312: 'dvd', 313: '후회', 314: '좋았던', 315: '드라마', 316: '가슴이', 317: '주는', 318: '시작부터', 319: '배우들', 320: '1편보다', 321: '재밌고', 322: '몰입감', 323: '있다.', 324: '연기도', 325: '특히', 326: '카메라', 327: '문득', 328: '얼굴이', 329: '배우', 330: '지금', 331: '불편한', 332: '엉성한', 333: '이딴걸', 334: '절로', 335: '전체적으로', 336: '넘', 337: '재밌었어요', 338: 'ㅎㅎ', 339: '딱', 340: '적당한', 341: '영화...', 342: '만든', 343: '코미디.', 344: '뭐', 345: '하나', 346: '제대로', 347: '없다', 348: '지금도', 349: ' ...

# %%
# to_indices
example_sentence = tr_dataset['document'][0]
tokenized_sentence = split_eojeol(example_sentence)
transformed_sentence = vocab.to_indices(tokenized_sentence)
print(example_sentence)
print(tokenized_sentence)
print(transformed_sentence)
# Out:
# 60년대 각본을 가져다가 만든거 같이 진부하고 춤도 이박사 춤이 더 나을거 같음
# ['60년대', '각본을', '가져다가', '만든거', '같이', '진부하고', '춤도', '이박사', '춤이', '더', '나을거', '같음']
# [0, 2, 0, 0, 3, 4, 0, 0, 0, 5, 0, 6]

# %%
# to_tokens
print(vocab.to_tokens(transformed_sentence))
# Out:
# ['<unk>', '각본을', '<unk>', '<unk>', '같이', '진부하고', '<unk>', '<unk>', '<unk>', '더', '<unk>', '같음']

# %% [markdown]
# ### How to use `Tokenizer`
# 위의 `Vocab` class의 활용 형태를 보면 `split_fn`으로 활용하는 `split_eojeol` function의 결과를 input을 기본적으로 받습니다. `Vocab` class의 instance와 `split_fn`으로 활용하는 `split_eojeol` function을 input으로 받아 전처리를 해주는 `Tokenizer` class를 활용할 수 있습니다.

# %%
help(Tokenizer)
# Out:
# Help on class Tokenizer in module utils:
#
# class Tokenizer(builtins.object)
#  |  Tokenizer class
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, vocab:utils.Vocab, split_fn:Callable[[str], List[str]], pad_fn:Callable[[List[int]], List[int]]=None) -> None
#  |      Instantiating Tokenizer class
#  |
#  |      Args:
#  |          vocab (model.utils.Vocab): the instance of model.utils.Vocab created from specific split_fn
#  |          split_fn (Callable): a function that can act as a splitter
#  |          pad_fn (Callable): a function that can act as a padder
#  |
#  |  split(self, string:str) -> List[str]
#  |
#  |  split_and_transform(self, string:str) -> List[int]
#  |
#  |  transform(self, list_of_tokens:List[str]) -> List[int]
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  vocab

# %%
tokenizer = Tokenizer(vocab, split_eojeol)

# %%
# split, transform, split_and_transform
example_sentence = tr_dataset['document'][0]
tokenized_sentence = tokenizer.split(example_sentence)
transformed_sentence = tokenizer.transform(tokenized_sentence)
print(example_sentence)
print(tokenized_sentence)
print(transformed_sentence)
print(tokenizer.split_and_transform(example_sentence))
# Out:
# 60년대 각본을 가져다가 만든거 같이 진부하고 춤도 이박사 춤이 더 나을거 같음
# ['60년대', '각본을', '가져다가', '만든거', '같이', '진부하고', '춤도', '이박사', '춤이', '더', '나을거', '같음']
# [0, 2, 0, 0, 3, 4, 0, 0, 0, 5, 0, 6]
# [0, 2, 0, 0, 3, 4, 0, 0, 0, 5, 0, 6]
